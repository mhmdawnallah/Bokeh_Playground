# %%
# Making a basic Bokeh Line Graph

# importing Bokeh 
from bokeh.plotting import figure
from bokeh.io import output_file, show

#prepare some fake data
x=[1,2,3,4,5]
y=[6,7,8,9,10]

#prepare the output file
output_file("Line.html")

#Create Figure Object
f = figure()

#Create Line Plot

f.line(x,y)
f.circle([i*2 for i in x],[i*2 for i in y])

show(f)

# %%
# Making a basic Bokeh Triangle Graph

# importing Bokeh 
from bokeh.plotting import figure
from bokeh.io import output_file, show

#prepare some fake data
x=[3,7.75,10]
y=[3,6,9]

#prepare the output file
output_file("Triangle.html")

#Create Figure Object
f = figure()

#Create Line Plot

f.triangle(x,y)

show(f)

# %%
# Making a basic Bokeh Circle Graph

# importing Bokeh 
from bokeh.plotting import figure
from bokeh.io import output_file, show

#prepare some fake data
x=[3,7.75,10]
y=[3,6,9]

#prepare the output file
output_file("Circle.html")

#Create Figure Object
f = figure()

#Create Line Plot

f.circle(x,y)

show(f)

# %%
# Making a basic Bokeh Line Graph

# importing Bokeh and pandas
from bokeh.plotting import figure
from bokeh.io import output_file, show
import pandas as pd

#prepare some fake data
df = pd.read_csv("bachelors.csv")
years = df['Year']
engineering = df['Engineering']

#prepare the output file
output_file("bachelors.html")

#Create Figure Object
f = figure()

#Create Line Plot

f.line(years,engineering)

show(f)

# %%
# Making a basic Bokeh Line Graph

# importing Bokeh and pandas
from bokeh.plotting import figure
from bokeh.io import output_file, show
import pandas as pd

#prepare some fake data
df = pd.read_csv("bachelors.csv")
years = df['Year']
engineering = df['Engineering']


#Create Figure Object
f = figure(plot_width=500,plot_height=400,tools="pan")
f.title.text="American Womans with Bachelors in Engineering"
f.title.text_color="Gray"
f.title.text_font="times"
f.title.text_font_style="bold"
f.xaxis.minor_tick_line_color=None
f.yaxis.minor_tick_line_color=None

f.xaxis.axis_label="Year"
f.yaxis.axis_label="Engineering"

#prepare the output file
output_file("bachelors.html")

#Create Line Plot

f.line(years,engineering)

show(f)

# %%
# Making a basic Bokeh Line Graph

# importing Bokeh and pandas
from bokeh.plotting import figure
from bokeh.io import output_file, show
import pandas as pd

#prepare some fake data
df = pd.read_csv("bachelors.csv")
years = df['Year']
engineering = df['Engineering']


#Create Figure Object
f = figure(plot_width=500,plot_height=400,tools="pan")
f.title.text="American Womans with Bachelors in Engineering"
f.title.text_color="Gray"
f.title.text_font="times"
f.title.text_font_style="bold"
f.xaxis.minor_tick_line_color=None
f.yaxis.minor_tick_line_color=None

f.xaxis.axis_label="Year"
f.yaxis.axis_label="Engineering"

#prepare the output file
output_file("bachelors.html")

#Create Line Plot

f.line(years,engineering)

show(f)

# %%
# Making a basic Bokeh Line Graph

# importing Bokeh and pandas
from bokeh.plotting import figure
from bokeh.io import output_file, show
import pandas as pd

#prepare some fake data
df = pd.read_excel("verlegenhuken.xlsx")
temp = df['Temperature'] / 10
pressure = df['Pressure'] / 10


#Create Figure Object
f = figure(plot_width=500,plot_height=400,tools="pan")

f.title.text="Temperature and Air Pressure"
f.title.text_color="Gray"
f.title.text_font="times"
f.title.text_font_style="bold"
f.xaxis.minor_tick_line_color=None
f.yaxis.minor_tick_line_color=None

f.xaxis.axis_label="Temperature(°C)"
f.yaxis.axis_label="Pressure(nPa))"





#Create Scatter Plot
f.circle(temp,pressure, size=0.5, color="red", alpha=0.5)

#prepare the output file
output_file("verlegenhuken.html")

show(f)

# %%
from bokeh.plotting import figure,output_file, show
import pandas as pd

df = pd.read_csv("adbe.csv",parse_dates=["Date"])

p = figure(width=500,height=300,x_axis_type="datetime",sizing_mode="scale_both")

p.line(df["Date"],df["Close"],color="Orange",alpha=0.5)

output_file("Timeseries.html")
show(p)

# %%
from bokeh.plotting import figure,output_file, show
import pandas as pd

df = pd.read_csv("Times.csv",parse_dates=["Start","End"])
#Drop the first column
df = df.iloc[: , 1:]
p = figure(width=500,height=300,x_axis_type="datetime",y_axis_type="datetime")

p.quad(top=df[top, bottom=[1, 2, 3], left=[1, 2, 3],
       right=[1.2, 2.5, 3.7], color="#B3DE69")
output_file("VideoTimeSeries.html")
show(p)
